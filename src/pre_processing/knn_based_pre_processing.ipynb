# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import pickle as pkl
from os.path import join

# %%
DATA_PATH= join("..", "..", "resources", "database", "Vegetable_market.csv")

data = pd.read_csv(DATA_PATH)

# %%
data
# Out:
#     Vegetable  Season Month  Temp Deasaster Happen in last 3month  \
# 0      potato  winter   jan    15                              no
# 1     tomato   winter   jan    15                              no
# 2        peas  winter   jan    15                              no
# 3      pumkin  winter   jan    15                              no
# 4    cucumber  winter   jan    15                              no
# ..        ...     ...   ...   ...                             ...
# 116   brinjal  winter   jan    15                             yes
# 117    ginger  winter   jan    15                              no
# 118    potato  summer   apr    32                              no
# 119      peas  summer   apr    33                              no
# 120    radish  summer   apr    32                              no
#
#     Vegetable condition  Price per kg
# 0                 fresh            20
# 1                 fresh            50
# 2                 fresh            70
# 3                 fresh            25
# 4                 fresh            20
# ..                  ...           ...
# 116               fresh            33
# 117               fresh            88
# 118               fresh            24
# 119               fresh            33
# 120               fresh             9
#
# [121 rows x 7 columns]

# %%
data_x = data.iloc[:, :-1]

data_x
# Out:
#     Vegetable  Season Month  Temp Deasaster Happen in last 3month  \
# 0      potato  winter   jan    15                              no
# 1     tomato   winter   jan    15                              no
# 2        peas  winter   jan    15                              no
# 3      pumkin  winter   jan    15                              no
# 4    cucumber  winter   jan    15                              no
# ..        ...     ...   ...   ...                             ...
# 116   brinjal  winter   jan    15                             yes
# 117    ginger  winter   jan    15                              no
# 118    potato  summer   apr    32                              no
# 119      peas  summer   apr    33                              no
# 120    radish  summer   apr    32                              no
#
#     Vegetable condition
# 0                 fresh
# 1                 fresh
# 2                 fresh
# 3                 fresh
# 4                 fresh
# ..                  ...
# 116               fresh
# 117               fresh
# 118               fresh
# 119               fresh
# 120               fresh
#
# [121 rows x 6 columns]

# %%
data_y = data.iloc[:, -1]

data_y = data_y.values.reshape(-1, 1)

data_y
# Out:
# array([[ 20],
#        [ 50],
#        [ 70],
#        [ 25],
#        [ 20],
#        [130],
#        [ 10],
#        [ 35],
#        [ 35],
#        [ 45],
#        [150],
#        [ 45],
#        [ 20],
#        [ 80],
#        [ 30],
#        [ 20],
#        [ 70],
#        [ 20],
#        [ 25],
#        [100],
#        [ 30],
#        [ 80],
#        [ 50],
#        [ 60],
#        [ 25],
#        [ 70],
#        [ 70],
#        [ 20],
#        [130],
#        [170],
#        [ 40],
#        [ 20],
#        [200],
#        [ 15],
#        [ 10],
#        [ 40],
#        [200],
#        [ 40],
#        [250],
#        [ 90],
#        [ 16],
#        [ 30],
#        [ 40],
#        [ 15],
#        [ 12],
#        [ 50],
#        [ 15],
#        [ 25],
#        [ 28],
#        [ 35],
#        [120],
#        [ 75],
#        [ 18],
#        [ 80],
#        [ 40],
#        [ 20],
#        [ 70],
#        [ 70],
#        [ 25],
#        [100],
#        [ 30],
#        [120],
#        [ 50],
#        [ 60],
#        [ 25],
#        [ 80],
#        [ 15],
#        [ 45],
#        [190],
#        [ 50],
#        [210],
#        [130],
#        [ 10],
#        [ 25],
#        [ 42],
#        [ 20],
#        [ 15],
#        [ 55],
#        [ 20],
#        [ 29],
#        [ 32],
#        [ 20],
#        [132],
#        [ 60],
#        [ 21],
#        [ 75],
#        [ 35],
#        [ 19],
#        [ 32],
#        [ 90],
#        [ 22],
#        [ 35],
#        [ 21],
#        [ 90],
#        [ 33],
#        [ 55],
#        [ 30],
#        [ 45],
#        [170],
#        [150],
#        [ 24],
#        [ 30],
#        [ 35],
#        [ 23],
#        [ 21],
#        [ 53],
#        [ 27],
#        [ 32],
#        [ 24],
#        [ 22],
#        [123],
#        [ 55],
#        [ 21],
#        [ 90],
#        [ 25],
#        [ 21],
#        [ 33],
#        [ 88],
#        [ 24],
#        [ 33],
#        [  9]])

# %%
def encode_data(data: pd.Series) -> pd.DataFrame:
    encoder = LabelEncoder()
    data_encoded = encoder.fit_transform(data)

    return data_encoded

# %%
def scale_data(data: pd.Series) -> pd.DataFrame:
    scaler = StandardScaler()
    
    data_scaled = scaler.fit_transform(data)

    return data_scaled

# %%
def one_hot_encoding(data: pd.DataFrame) -> pd.DataFrame:
    encoder = OneHotEncoder(sparse_output=False)

    data_encoded = encoder.fit_transform(data)

    df = pd.DataFrame(data=data_encoded, columns=encoder.get_feature_names_out())

    return df

# %%
x_categorical = ['Vegetable', 'Season',
                'Month', 'Deasaster Happen in last 3month',
                'Vegetable condition']

x_numerical = ["Temp"]

# %%
x_encoded = data_x[x_categorical].apply(lambda x: encode_data(x))

x_encoded
# Out:
#      Vegetable  Season  Month  Deasaster Happen in last 3month  \
# 0           13       4      4                                0
# 1           16       4      4                                0
# 2           11       4      4                                0
# 3           14       4      4                                0
# 4            6       4      4                                0
# ..         ...     ...    ...                              ...
# 116          2       4      4                                1
# 117          8       4      4                                0
# 118         13       3      1                                0
# 119         11       3      1                                0
# 120         15       3      1                                0
#
#      Vegetable condition
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 116                    1
# 117                    1
# 118                    1
# 119                    1
# 120                    1
#
# [121 rows x 5 columns]

# %%
data_x_transformed = x_encoded

data_x_transformed.insert(3, "Temp", data_x["Temp"])

data_x_transformed
# Out:
#      Vegetable  Season  Month  Temp  Deasaster Happen in last 3month  \
# 0           13       4      4    15                                0
# 1           16       4      4    15                                0
# 2           11       4      4    15                                0
# 3           14       4      4    15                                0
# 4            6       4      4    15                                0
# ..         ...     ...    ...   ...                              ...
# 116          2       4      4    15                                1
# 117          8       4      4    15                                0
# 118         13       3      1    32                                0
# 119         11       3      1    33                                0
# 120         15       3      1    32                                0
#
#      Vegetable condition
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 116                    1
# 117                    1
# 118                    1
# 119                    1
# 120                    1
#
# [121 rows x 6 columns]

# %%
data_x_scaled = data_x_transformed.apply(lambda x: scale_data(x.values.reshape(-1, 1)).squeeze())

# %%
data_x_scaled
# Out:
#      Vegetable    Season     Month      Temp  Deasaster Happen in last 3month  \
# 0     0.845810  0.812753  0.151192 -1.065944                        -0.599625
# 1     1.450197  0.812753  0.151192 -1.065944                        -0.599625
# 2     0.442885  0.812753  0.151192 -1.065944                        -0.599625
# 3     1.047272  0.812753  0.151192 -1.065944                        -0.599625
# 4    -0.564428  0.812753  0.151192 -1.065944                        -0.599625
# ..         ...       ...       ...       ...                              ...
# 116  -1.370278  0.812753  0.151192 -1.065944                         1.667708
# 117  -0.161503  0.812753  0.151192 -1.065944                        -0.599625
# 118   0.845810 -0.049906 -1.293088  0.765841                        -0.599625
# 119   0.442885 -0.049906 -1.293088  0.873593                        -0.599625
# 120   1.248735 -0.049906 -1.293088  0.765841                        -0.599625
#
#      Vegetable condition
# 0              -0.067293
# 1              -0.067293
# 2              -0.067293
# 3              -0.067293
# 4              -0.067293
# ..                   ...
# 116            -0.067293
# 117            -0.067293
# 118            -0.067293
# 119            -0.067293
# 120            -0.067293
#
# [121 rows x 6 columns]

# %%
data_y_scaled = scale_data(data_y)

# %%
data_y_scaled
# Out:
# array([[-0.7274458 ],
#        [-0.10975498],
#        [ 0.3020389 ],
#        [-0.62449733],
#        [-0.7274458 ],
#        [ 1.53742054],
#        [-0.93334274],
#        [-0.41860039],
#        [-0.41860039],
#        [-0.21270345],
#        [ 1.94921442],
#        [-0.21270345],
#        [-0.7274458 ],
#        [ 0.50793584],
#        [-0.52154886],
#        [-0.7274458 ],
#        [ 0.3020389 ],
#        [-0.7274458 ],
#        [-0.62449733],
#        [ 0.91972972],
#        [-0.52154886],
#        [ 0.50793584],
#        [-0.10975498],
#        [ 0.09614196],
#        [-0.62449733],
#        [ 0.3020389 ],
#        [ 0.3020389 ],
#        [-0.7274458 ],
#        [ 1.53742054],
#        [ 2.3610083 ],
#        [-0.31565192],
#        [-0.7274458 ],
#        [ 2.97869913],
#        [-0.83039427],
#        [-0.93334274],
#        [-0.31565192],
#        [ 2.97869913],
#        [-0.31565192],
#        [ 4.00818383],
#        [ 0.71383278],
#        [-0.80980458],
#        [-0.52154886],
#        [-0.31565192],
#        [-0.83039427],
#        [-0.89216335],
#        [-0.10975498],
#        [-0.83039427],
#        [-0.62449733],
#        [-0.56272825],
#        [-0.41860039],
#        [ 1.3315236 ],
#        [ 0.40498737],
#        [-0.76862519],
#        [ 0.50793584],
#        [-0.31565192],
#        [-0.7274458 ],
#        [ 0.3020389 ],
#        [ 0.3020389 ],
#        [-0.62449733],
#        [ 0.91972972],
#        [-0.52154886],
#        [ 1.3315236 ],
#        [-0.10975498],
#        [ 0.09614196],
#        [-0.62449733],
#        [ 0.50793584],
#        [-0.83039427],
#        [-0.21270345],
#        [ 2.77280219],
#        [-0.10975498],
#        [ 3.18459607],
#        [ 1.53742054],
#        [-0.93334274],
#        [-0.62449733],
#        [-0.27447253],
#        [-0.7274458 ],
#        [-0.83039427],
#        [-0.00680651],
#        [-0.7274458 ],
#        [-0.54213856],
#        [-0.48036947],
#        [-0.7274458 ],
#        [ 1.57859993],
#        [ 0.09614196],
#        [-0.70685611],
#        [ 0.40498737],
#        [-0.41860039],
#        [-0.7480355 ],
#        [-0.48036947],
#        [ 0.71383278],
#        [-0.68626641],
#        [-0.41860039],
#        [-0.70685611],
#        [ 0.71383278],
#        [-0.45977978],
#        [-0.00680651],
#        [-0.52154886],
#        [-0.21270345],
#        [ 2.3610083 ],
#        [ 1.94921442],
#        [-0.64508703],
#        [-0.52154886],
#        [-0.41860039],
#        [-0.66567672],
#        [-0.70685611],
#        [-0.0479859 ],
#        [-0.58331794],
#        [-0.48036947],
#        [-0.64508703],
#        [-0.68626641],
#        [ 1.39329268],
#        [-0.00680651],
#        [-0.70685611],
#        [ 0.71383278],
#        [-0.62449733],
#        [-0.70685611],
#        [-0.45977978],
#        [ 0.67265339],
#        [-0.64508703],
#        [-0.45977978],
#        [-0.95393244]])

# %%
x_train, x_test, y_train, y_test = train_test_split(
                                    data_x_scaled, data_y,
                                    test_size=0.25, random_state=0
)

# %%
KNN_BASED_DATA_PATH = join("..", "..", "resources", "database", "knn_classifier_data.pkl")

with open(KNN_BASED_DATA_PATH, "wb") as file:
    pkl.dump([x_train, x_test, y_train, y_test], file)

# %%
x_train, x_test, y_train, y_test = train_test_split(
                                    data_x_scaled, data_y_scaled,
                                    test_size=0.25, random_state=0
)

# %%
KNN_BASED_DATA_PATH = join("..", "..", "resources", "database", "knn_regressor_data.pkl")

with open(KNN_BASED_DATA_PATH, "wb") as file:
    pkl.dump([x_train, x_test, y_train, y_test], file)
